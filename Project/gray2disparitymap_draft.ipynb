# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
imageR = cv2.imread('right.png')
imageL = cv2.imread('left.png')

# %%
plt.imshow(image)
plt.show()

# %%
imageR_color2grayscale = cv2.cvtColor(imageR, cv2.COLOR_BGR2GRAY)
imageL_color2grayscale = cv2.cvtColor(imageL, cv2.COLOR_BGR2GRAY)

# %%
imageR_color2grayscale = cv2.cvtColor(imageR, cv2.COLOR_BGR2GRAY)
imageL_color2grayscale = cv2.cvtColor(imageL, cv2.COLOR_BGR2GRAY)
plt.figure(figsize=(20, 10))

plt.subplot(1,3,1)
plt.imshow(imageR_color2grayscale, cmap='gray', vmin=0, vmax=255)
plt.subplot(1,3,2)
plt.imshow(imageL_color2grayscale, cmap='gray', vmin=0, vmax=255)
plt.subplot(1,3,3)
stereo = cv2.StereoBM_create(numDisparities=16, blockSize=11)
disparity = stereo.compute(imageR_color2grayscale,imageL_color2grayscale)
plt.imshow(disparity,'gray')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-989055bad590> in <module>
# ----> 1 imageR_color2grayscale = cv2.cvtColor(imageR, cv2.COLOR_BGR2GRAY)
#       2 imageL_color2grayscale = cv2.cvtColor(imageL, cv2.COLOR_BGR2GRAY)
#       3 plt.figure(figsize=(20, 10))
#       4
#       5 plt.subplot(1,3,1)
#
# NameError: name 'cv2' is not defined

# %%
stereo = cv2.StereoBM_create(numDisparities=16, blockSize=15)
disparity = stereo.compute(imageR_color2grayscale,imageL_color2grayscale)
plt.imshow(disparity,'gray')
plt.show()
